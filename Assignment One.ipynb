# %% [markdown]
# # Assignment One

# %% [markdown]
# ## Luke Jenkins

# %%
# Luke Jenkins
# CS-150
# Assignment One
# Version One

# %% [markdown]
# >I like pepperoni
#
# * Variables and Simple Data Types
# * Introducing Lists,Tuples
# * If Statements
# * Dictionaries
# * Loops
# * While loops
# * Functions
# * Classes
# * Numpy

# %% [markdown]
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.

# %% [markdown]
# **I like pizza**

# %% [markdown]
# *I like bread too*

# %% [markdown]
# <a href="https://github.com/login?">https://github.com/mintslim</a>

# %% [markdown]
# ![Python Logo](https://www.python.org/static/community_logos/python-logo-master-v3-TM.png)
# ![image.png](attachment:image.png)
